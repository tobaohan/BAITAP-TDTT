# %%
#bai1
a=float(input())
b=float(input())
print(a*b,2*(a+b))
# Out:
# 2.0 6.0

# %%
#bai2
r=float(input())
pi=3.14
print(pi*r*r,2*pi*r)
# Out:
# 12.56 12.56

# %%
#bai3
a=float(input())
b=float(input())
c=float(input())
if a+b<=c or a+c<=b or b+c<=a:
 print('Khong la ba canh cua mot tam giac')
else:
 if a==b==c:print('Tam giac deu')
 elif a==b or a==c or b==c:print('Tam giac can')
 elif a*a+b*b==c*c or a*a+c*c==b*b or b*b+c*c==a*a:print('Tam giac vuong')
 else:print('Tam giac thuong')
 p=(a+b+c)/2
 s=(p*(p-a)*(p-b)*(p-c))**0.5
 print(s,a+b+c)
# Out:
# Khong la ba canh cua mot tam giac

# %%
#bai4
a=float(input())
b=float(input())
if a==0:
 print('Vo nghiem' if b!=0 else 'Vo so nghiem')
else:
 print(-b/a)
# Out:
# -2.0

# %%
#bai5
a=float(input())
b=float(input())
c=float(input())
if a==0:
 print('Khong phai pt bac 2')
else:
 d=b*b-4*a*c
 if d<0:print('Vo nghiem')
 elif d==0:print(-b/(2*a))
 else:
  x1=(-b+d**0.5)/(2*a)
  x2=(-b-d**0.5)/(2*a)
  print(x1,x2)
# Out:
# Vo nghiem

# %%
#bai6
a=float(input())
b=float(input())
c=float(input())
d=float(input())
print(max(a,b,c,d))
# Out:
# 4.0

# %%
#bai7
a=float(input())
b=float(input())
c=float(input())
d=float(input())
print(min(a,b,c,d))
# Out:
# 1.0

# %%
#bai8
a=float(input())
b=float(input())
c=float(input())
d=float(input())
m=float(input())
n=float(input())
D=a*d-b*c
if D==0:print('Vo nghiem')
else:
 x=(m*d-b*n)/D
 y=(a*n-m*c)/D
 print(x,y)
# Out:
# -0.0 0.5

# %%
#bai9
x=int(input())
h=x//3600
m=(x%3600)//60
s=x%60
print(h,m,s)
# Out:
# 0 0 1

# %%
#bai10
x0=float(input())
y0=float(input())
r=float(input())
x=float(input())
y=float(input())
if (x-x0)**2+(y-y0)**2<=r*r:print('Thuoc')
else:print('Khong thuoc')
# Out:
# Thuoc

# %%
#bai11
x=float(input())
y=float(input())
print(x**y)
# Out:
# 1.0
